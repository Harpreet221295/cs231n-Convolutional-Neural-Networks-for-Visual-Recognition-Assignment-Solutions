# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.379639
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# **Your answer:** *Fill this in*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: 1.222252 analytic: 1.222252, relative error: 2.082761e-08
# numerical: 0.321924 analytic: 0.321924, relative error: 6.293292e-08
# numerical: 1.647548 analytic: 1.647547, relative error: 6.437640e-08
# numerical: -0.983618 analytic: -0.983619, relative error: 3.296705e-08
# numerical: 1.222232 analytic: 1.222232, relative error: 4.370573e-08
# numerical: -1.588318 analytic: -1.588318, relative error: 1.215712e-08
# numerical: -0.178688 analytic: -0.178688, relative error: 1.783620e-07
# numerical: -1.899334 analytic: -1.899334, relative error: 8.431298e-09
# numerical: 0.524947 analytic: 0.524946, relative error: 1.026393e-07
# numerical: 1.880296 analytic: 1.880296, relative error: 3.526388e-08
# numerical: 1.832480 analytic: 1.832480, relative error: 1.406572e-08
# numerical: -0.515362 analytic: -0.515362, relative error: 7.041488e-08
# numerical: 1.756460 analytic: 1.756460, relative error: 3.815744e-08
# numerical: -0.111323 analytic: -0.111323, relative error: 2.890826e-07
# numerical: -1.401775 analytic: -1.401775, relative error: 5.507615e-09
# numerical: -0.382091 analytic: -0.382091, relative error: 9.274673e-08
# numerical: -0.836534 analytic: -0.836534, relative error: 1.188610e-07
# numerical: -0.249373 analytic: -0.249373, relative error: 2.294263e-07
# numerical: 1.542766 analytic: 1.542766, relative error: 5.327566e-09
# numerical: 1.855386 analytic: 1.855386, relative error: 4.441352e-08

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.379639e+00 computed in 0.202327s
# vectorized loss: 2.379639e+00 computed in 0.017460s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
val_list = []
softmax_model_list = []
best_val = -1
best_softmax = None
learning_rates = np.linspace(1e-7,5e-7,5)
regularization_strengths = np.linspace(2e4, 5e4,5)

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
for lr in learning_rates:
    for reg in regularization_strengths:
        softmax_classifier = Softmax()
        softmax_classifier.train(X_train,y_train,lr,reg,1000,200,verbose=True)
        y_train_pred = softmax_classifier.predict(X_train)
        train_accuracy = np.mean(y_train_pred == y_train)
        y_val_pred = softmax_classifier.predict(X_val)
        val_accuracy = np.mean(y_val_pred == y_val)
        val_list.append(val_accuracy)
        softmax_model_list.append(softmax_classifier)
        results[(lr,reg)] = (train_accuracy,val_accuracy)
        
################################################################################
#                              END OF YOUR CODE                                #
################################################################################


best_val_ind = np.argmax(val_list)
best_val = val_list[best_val_ind]
best_softmax = softmax_model_list[best_val_ind]

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# iteration 0 / 1000: loss 314.527852
# iteration 100 / 1000: loss 209.380561
# iteration 200 / 1000: loss 140.689449
# iteration 300 / 1000: loss 94.678550
# iteration 400 / 1000: loss 63.871397
# iteration 500 / 1000: loss 43.340612
# iteration 600 / 1000: loss 29.748376
# iteration 700 / 1000: loss 20.489870
# iteration 800 / 1000: loss 14.395390
# iteration 900 / 1000: loss 10.289467
# iteration 0 / 1000: loss 429.227346
# iteration 100 / 1000: loss 247.279997
# iteration 200 / 1000: loss 142.925478
# iteration 300 / 1000: loss 83.065061
# iteration 400 / 1000: loss 48.544279
# iteration 500 / 1000: loss 28.830611
# iteration 600 / 1000: loss 17.426322
# iteration 700 / 1000: loss 10.853594
# iteration 800 / 1000: loss 7.181370
# iteration 900 / 1000: loss 4.955120
# iteration 0 / 1000: loss 538.795398
# iteration 100 / 1000: loss 266.759944
# iteration 200 / 1000: loss 133.073646
# iteration 300 / 1000: loss 66.779220
# iteration 400 / 1000: loss 34.193200
# iteration 500 / 1000: loss 17.903850
# iteration 600 / 1000: loss 9.887977
# iteration 700 / 1000: loss 5.913994
# iteration 800 / 1000: loss 3.948266
# iteration 900 / 1000: loss 2.975652
# iteration 0 / 1000: loss 660.747066
# iteration 100 / 1000: loss 281.866673
# iteration 200 / 1000: loss 121.102023
# iteration 300 / 1000: loss 52.733174
# iteration 400 / 1000: loss 23.552747
# iteration 500 / 1000: loss 11.227780
# iteration 600 / 1000: loss 6.006410
# iteration 700 / 1000: loss 3.766795
# iteration 800 / 1000: loss 2.801858
# iteration 900 / 1000: loss 2.366948
# iteration 0 / 1000: loss 775.594232
# iteration 100 / 1000: loss 285.048444
# iteration 200 / 1000: loss 105.610015
# iteration 300 / 1000: loss 39.994617
# iteration 400 / 1000: loss 15.980626
# iteration 500 / 1000: loss 7.182661
# iteration 600 / 1000: loss 3.942770
# iteration 700 / 1000: loss 2.823459
# iteration 800 / 1000: loss 2.394162
# iteration 900 / 1000: loss 2.144434
# iteration 0 / 1000: loss 311.285156
# iteration 100 / 1000: loss 139.325053
# iteration 200 / 1000: loss 63.156033
# iteration 300 / 1000: loss 29.341080
# iteration 400 / 1000: loss 14.257211
# iteration 500 / 1000: loss 7.540539
# iteration 600 / 1000: loss 4.434803
# iteration 700 / 1000: loss 3.102752
# iteration 800 / 1000: loss 2.524939
# iteration 900 / 1000: loss 2.220155
# iteration 0 / 1000: loss 426.210576
# iteration 100 / 1000: loss 141.451585
# iteration 200 / 1000: loss 48.112551
# iteration 300 / 1000: loss 17.212867
# iteration 400 / 1000: loss 7.079484
# iteration 500 / 1000: loss 3.668849
# iteration 600 / 1000: loss 2.632946
# iteration 700 / 1000: loss 2.178276
# iteration 800 / 1000: loss 2.083692
# iteration 900 / 1000: loss 2.052049
# iteration 0 / 1000: loss 541.066593
# iteration 100 / 1000: loss 133.342735
# iteration 200 / 1000: loss 34.027846
# iteration 300 / 1000: loss 9.843226
# iteration 400 / 1000: loss 3.988501
# iteration 500 / 1000: loss 2.486206
# iteration 600 / 1000: loss 2.107289
# iteration 700 / 1000: loss 2.134737
# iteration 800 / 1000: loss 2.021177
# iteration 900 / 1000: loss 2.049846
# iteration 0 / 1000: loss 648.388035
# iteration 100 / 1000: loss 118.313099
# iteration 200 / 1000: loss 23.092248
# iteration 300 / 1000: loss 5.868934
# iteration 400 / 1000: loss 2.769761
# iteration 500 / 1000: loss 2.188744
# iteration 600 / 1000: loss 2.032844
# iteration 700 / 1000: loss 2.043632
# iteration 800 / 1000: loss 2.107444
# iteration 900 / 1000: loss 2.077760
# iteration 0 / 1000: loss 769.262753
# iteration 100 / 1000: loss 104.141819
# iteration 200 / 1000: loss 15.700535
# iteration 300 / 1000: loss 3.921180
# iteration 400 / 1000: loss 2.319821
# iteration 500 / 1000: loss 2.081673
# iteration 600 / 1000: loss 2.090009
# iteration 700 / 1000: loss 2.081240
# iteration 800 / 1000: loss 2.142821
# iteration 900 / 1000: loss 2.149084
# iteration 0 / 1000: loss 311.764206
# iteration 100 / 1000: loss 93.860159
# iteration 200 / 1000: loss 29.459001
# iteration 300 / 1000: loss 10.138136
# iteration 400 / 1000: loss 4.404505
# iteration 500 / 1000: loss 2.720474
# iteration 600 / 1000: loss 2.212273
# iteration 700 / 1000: loss 2.083797
# iteration 800 / 1000: loss 1.995858
# iteration 900 / 1000: loss 2.001644
# iteration 0 / 1000: loss 430.016817
# iteration 100 / 1000: loss 82.797388
# iteration 200 / 1000: loss 17.299714
# iteration 300 / 1000: loss 4.923996
# iteration 400 / 1000: loss 2.575617
# iteration 500 / 1000: loss 2.089760
# iteration 600 / 1000: loss 1.971589
# iteration 700 / 1000: loss 2.021738
# iteration 800 / 1000: loss 2.044206
# iteration 900 / 1000: loss 2.094032
# iteration 0 / 1000: loss 546.768057
# iteration 100 / 1000: loss 67.207142
# iteration 200 / 1000: loss 9.943887
# iteration 300 / 1000: loss 2.971574
# iteration 400 / 1000: loss 2.206427
# iteration 500 / 1000: loss 2.070642
# iteration 600 / 1000: loss 2.080719
# iteration 700 / 1000: loss 2.044921
# iteration 800 / 1000: loss 1.989911
# iteration 900 / 1000: loss 2.047977
# iteration 0 / 1000: loss 665.727320
# iteration 100 / 1000: loss 52.585430
# iteration 200 / 1000: loss 5.923865
# iteration 300 / 1000: loss 2.365427
# iteration 400 / 1000: loss 2.099695
# iteration 500 / 1000: loss 2.164588
# iteration 600 / 1000: loss 2.018179
# iteration 700 / 1000: loss 2.069674
# iteration 800 / 1000: loss 2.039539
# iteration 900 / 1000: loss 2.033568
# iteration 0 / 1000: loss 772.287548
# iteration 100 / 1000: loss 39.297197
# iteration 200 / 1000: loss 3.847867
# iteration 300 / 1000: loss 2.121792
# iteration 400 / 1000: loss 2.111741
# iteration 500 / 1000: loss 2.125324
# iteration 600 / 1000: loss 2.093686
# iteration 700 / 1000: loss 2.026680
# iteration 800 / 1000: loss 2.096211
# iteration 900 / 1000: loss 2.053123
# iteration 0 / 1000: loss 314.626159
# iteration 100 / 1000: loss 63.715092
# iteration 200 / 1000: loss 14.377662
# iteration 300 / 1000: loss 4.453334
# iteration 400 / 1000: loss 2.575302
# iteration 500 / 1000: loss 2.187464
# iteration 600 / 1000: loss 2.014079
# iteration 700 / 1000: loss 2.022818
# iteration 800 / 1000: loss 1.948681
# iteration 900 / 1000: loss 2.000732
# iteration 0 / 1000: loss 423.549017
# iteration 100 / 1000: loss 47.643693
# iteration 200 / 1000: loss 7.019874
# iteration 300 / 1000: loss 2.580267
# iteration 400 / 1000: loss 2.075796
# iteration 500 / 1000: loss 1.924539
# iteration 600 / 1000: loss 2.115533
# iteration 700 / 1000: loss 1.987733
# iteration 800 / 1000: loss 2.012148
# iteration 900 / 1000: loss 2.090964
# iteration 0 / 1000: loss 536.644004
# iteration 100 / 1000: loss 33.506182
# iteration 200 / 1000: loss 3.919977
# iteration 300 / 1000: loss 2.194547
# iteration 400 / 1000: loss 2.055806
# iteration 500 / 1000: loss 2.075892
# iteration 600 / 1000: loss 2.091549
# iteration 700 / 1000: loss 2.060707
# iteration 800 / 1000: loss 2.119640
# iteration 900 / 1000: loss 2.115642
# iteration 0 / 1000: loss 659.902797
# iteration 100 / 1000: loss 23.224021
# iteration 200 / 1000: loss 2.721340
# iteration 300 / 1000: loss 2.088269
# iteration 400 / 1000: loss 2.097656
# iteration 500 / 1000: loss 2.088724
# iteration 600 / 1000: loss 2.043018
# iteration 700 / 1000: loss 2.098160
# iteration 800 / 1000: loss 2.089225
# iteration 900 / 1000: loss 2.028535
# iteration 0 / 1000: loss 769.580904
# iteration 100 / 1000: loss 15.453377
# iteration 200 / 1000: loss 2.333328
# iteration 300 / 1000: loss 2.107185
# iteration 400 / 1000: loss 2.069873
# iteration 500 / 1000: loss 2.149674
# iteration 600 / 1000: loss 2.071805
# iteration 700 / 1000: loss 2.057382
# iteration 800 / 1000: loss 2.105399
# iteration 900 / 1000: loss 2.066134
# iteration 0 / 1000: loss 313.176731
# iteration 100 / 1000: loss 42.906890
# iteration 200 / 1000: loss 7.426463
# iteration 300 / 1000: loss 2.755023
# iteration 400 / 1000: loss 2.106098
# iteration 500 / 1000: loss 2.011976
# iteration 600 / 1000: loss 2.046393
# iteration 700 / 1000: loss 1.948324
# iteration 800 / 1000: loss 2.067726
# iteration 900 / 1000: loss 2.021612
# iteration 0 / 1000: loss 428.281408
# iteration 100 / 1000: loss 28.342437
# iteration 200 / 1000: loss 3.567806
# iteration 300 / 1000: loss 2.100770
# iteration 400 / 1000: loss 1.999806
# iteration 500 / 1000: loss 2.032659
# iteration 600 / 1000: loss 1.979200
# iteration 700 / 1000: loss 2.023513
# iteration 800 / 1000: loss 2.026009
# iteration 900 / 1000: loss 2.060815
# iteration 0 / 1000: loss 545.259993
# iteration 100 / 1000: loss 17.715695
# iteration 200 / 1000: loss 2.536552
# iteration 300 / 1000: loss 2.053415
# iteration 400 / 1000: loss 2.096967
# iteration 500 / 1000: loss 2.119181
# iteration 600 / 1000: loss 2.058644
# iteration 700 / 1000: loss 2.069215
# iteration 800 / 1000: loss 2.039490
# iteration 900 / 1000: loss 2.054184
# iteration 0 / 1000: loss 651.161456
# iteration 100 / 1000: loss 10.800732
# iteration 200 / 1000: loss 2.168485
# iteration 300 / 1000: loss 2.024022
# iteration 400 / 1000: loss 2.000616
# iteration 500 / 1000: loss 2.055539
# iteration 600 / 1000: loss 2.096623
# iteration 700 / 1000: loss 2.090479
# iteration 800 / 1000: loss 2.060770
# iteration 900 / 1000: loss 2.099482
# iteration 0 / 1000: loss 779.650105
# iteration 100 / 1000: loss 6.911997
# iteration 200 / 1000: loss 2.097328
# iteration 300 / 1000: loss 2.122529
# iteration 400 / 1000: loss 2.081265
# iteration 500 / 1000: loss 2.077969
# iteration 600 / 1000: loss 2.120179
# iteration 700 / 1000: loss 2.170225
# iteration 800 / 1000: loss 2.057329
# iteration 900 / 1000: loss 2.038638
# lr 1.000000e-07 reg 2.000000e+04 train accuracy: 0.329531 val accuracy: 0.354000
# lr 1.000000e-07 reg 2.750000e+04 train accuracy: 0.341449 val accuracy: 0.363000
# lr 1.000000e-07 reg 3.500000e+04 train accuracy: 0.334714 val accuracy: 0.355000
# lr 1.000000e-07 reg 4.250000e+04 train accuracy: 0.337571 val accuracy: 0.360000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.326714 val accuracy: 0.347000
# lr 2.000000e-07 reg 2.000000e+04 train accuracy: 0.356673 val accuracy: 0.375000
# lr 2.000000e-07 reg 2.750000e+04 train accuracy: 0.348306 val accuracy: 0.357000
# lr 2.000000e-07 reg 3.500000e+04 train accuracy: 0.342041 val accuracy: 0.352000
# lr 2.000000e-07 reg 4.250000e+04 train accuracy: 0.331531 val accuracy: 0.346000
# lr 2.000000e-07 reg 5.000000e+04 train accuracy: 0.324959 val accuracy: 0.342000
# lr 3.000000e-07 reg 2.000000e+04 train accuracy: 0.352102 val accuracy: 0.368000
# lr 3.000000e-07 reg 2.750000e+04 train accuracy: 0.341735 val accuracy: 0.352000
# lr 3.000000e-07 reg 3.500000e+04 train accuracy: 0.343429 val accuracy: 0.348000
# lr 3.000000e-07 reg 4.250000e+04 train accuracy: 0.334184 val accuracy: 0.349000
# lr 3.000000e-07 reg 5.000000e+04 train accuracy: 0.329735 val accuracy: 0.345000
# lr 4.000000e-07 reg 2.000000e+04 train accuracy: 0.353796 val accuracy: 0.364000
# lr 4.000000e-07 reg 2.750000e+04 train accuracy: 0.348592 val accuracy: 0.363000
# lr 4.000000e-07 reg 3.500000e+04 train accuracy: 0.330163 val accuracy: 0.348000
# lr 4.000000e-07 reg 4.250000e+04 train accuracy: 0.327449 val accuracy: 0.337000
# lr 4.000000e-07 reg 5.000000e+04 train accuracy: 0.328571 val accuracy: 0.353000
# lr 5.000000e-07 reg 2.000000e+04 train accuracy: 0.352000 val accuracy: 0.370000
# lr 5.000000e-07 reg 2.750000e+04 train accuracy: 0.344776 val accuracy: 0.352000
# lr 5.000000e-07 reg 3.500000e+04 train accuracy: 0.324857 val accuracy: 0.352000
# lr 5.000000e-07 reg 4.250000e+04 train accuracy: 0.319388 val accuracy: 0.337000
# lr 5.000000e-07 reg 5.000000e+04 train accuracy: 0.329510 val accuracy: 0.338000
# best validation accuracy achieved during cross-validation: 0.375000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.362000

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i] - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
