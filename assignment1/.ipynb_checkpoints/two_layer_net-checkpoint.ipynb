# %% [markdown]
# # Implementing a Neural Network
# In this exercise we will develop a neural network with fully-connected layers to perform classification, and test it out on the CIFAR-10 dataset.

# %%
# A bit of setup

import numpy as np
import matplotlib.pyplot as plt

from cs231n.classifiers.neural_net import TwoLayerNet

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# We will use the class `TwoLayerNet` in the file `cs231n/classifiers/neural_net.py` to represent instances of our network. The network parameters are stored in the instance variable `self.params` where keys are string parameter names and values are numpy arrays. Below, we initialize toy data and a toy model that we will use to develop your implementation.

# %%
# Create a small net and some toy data to check your implementations.
# Note that we set the random seed for repeatable experiments.

input_size = 4
hidden_size = 10
num_classes = 3
num_inputs = 5

def init_toy_model():
    np.random.seed(0)
    return TwoLayerNet(input_size, hidden_size, num_classes, std=1e-1)

def init_toy_data():
    np.random.seed(1)
    X = 10 * np.random.randn(num_inputs, input_size)
    y = np.array([0, 1, 2, 2, 1])
    return X, y

net = init_toy_model()
X, y = init_toy_data()

# %% [markdown]
# # Forward pass: compute scores
# Open the file `cs231n/classifiers/neural_net.py` and look at the method `TwoLayerNet.loss`. This function is very similar to the loss functions you have written for the SVM and Softmax exercises: It takes the data and weights and computes the class scores, the loss, and the gradients on the parameters.
#
# Implement the first part of the forward pass which uses the weights and biases to compute the scores for all inputs.

# %%
scores = net.loss(X)
print('Your scores:')
print(scores)
print()
print('correct scores:')
correct_scores = np.asarray([
  [-0.81233741, -1.27654624, -0.70335995],
  [-0.17129677, -1.18803311, -0.47310444],
  [-0.51590475, -1.01354314, -0.8504215 ],
  [-0.15419291, -0.48629638, -0.52901952],
  [-0.00618733, -0.12435261, -0.15226949]])
print(correct_scores)
print()

# The difference should be very small. We get < 1e-7
print('Difference between your scores and correct scores:')
print(np.sum(np.abs(scores - correct_scores)))
# Out:
# Your scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# correct scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# Difference between your scores and correct scores:
# 3.68027207459e-08

# %% [markdown]
# # Forward pass: compute loss
# In the same function, implement the second part that computes the data and regularizaion loss.

# %%
loss, _ = net.loss(X, y, reg=0.05)
correct_loss = 1.30378789133

# should be very small, we get < 1e-12
print('Difference between your loss and correct loss:')
print(np.sum(np.abs(loss - correct_loss)))
# Out:
# Difference between your loss and correct loss:
# 1.79856129989e-13

# %% [markdown]
# # Backward pass
# Implement the rest of the function. This will compute the gradient of the loss with respect to the variables `W1`, `b1`, `W2`, and `b2`. Now that you (hopefully!) have a correctly implemented forward pass, you can debug your backward pass using a numeric gradient check:

# %%
from cs231n.gradient_check import eval_numerical_gradient

# Use numeric gradient checking to check your implementation of the backward pass.
# If your implementation is correct, the difference between the numeric and
# analytic gradients should be less than 1e-8 for each of W1, W2, b1, and b2.

loss, grads = net.loss(X, y, reg=0.05)

# these should all be less than 1e-8 or so
for param_name in grads:
    f = lambda W: net.loss(X, y, reg=0.05)[0]
    param_grad_num = eval_numerical_gradient(f, net.params[param_name], verbose=False)
    print('%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name])))
# Out:
# b1 max relative error: 2.738421e-09
# W1 max relative error: 3.561318e-09
# b2 max relative error: 4.447646e-11
# W2 max relative error: 3.440708e-09

# %% [markdown]
# # Train the network
# To train the network we will use stochastic gradient descent (SGD), similar to the SVM and Softmax classifiers. Look at the function `TwoLayerNet.train` and fill in the missing sections to implement the training procedure. This should be very similar to the training procedure you used for the SVM and Softmax classifiers. You will also have to implement `TwoLayerNet.predict`, as the training process periodically performs prediction to keep track of accuracy over time while the network trains.
#
# Once you have implemented the method, run the code below to train a two-layer network on toy data. You should achieve a training loss less than 0.2.

# %%
net = init_toy_model()
stats = net.train(X, y, X, y,
            learning_rate=1e-1, reg=5e-6,
            num_iters=100, verbose=False)

print('Final training loss: ', stats['loss_history'][-1])

# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# Final training loss:  0.0171496079387

# %% [markdown]
# # Load the data
# Now that you have implemented a two-layer network that passes gradient checks and works on toy data, it's time to load up our favorite CIFAR-10 data so we can use it to train a classifier on a real dataset.

# %%
from cs231n.data_utils import load_CIFAR10

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the two-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
        
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis=0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image

    # Reshape data to rows
    X_train = X_train.reshape(num_training, -1)
    X_val = X_val.reshape(num_validation, -1)
    X_test = X_test.reshape(num_test, -1)

    return X_train, y_train, X_val, y_val, X_test, y_test


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (49000, 3072)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3072)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3072)
# Test labels shape:  (1000,)

# %% [markdown]
# # Train a network
# To train our network we will use SGD with momentum. In addition, we will adjust the learning rate with an exponential learning rate schedule as optimization proceeds; after each epoch, we will reduce the learning rate by multiplying it by a decay rate.

# %%
input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10
net = TwoLayerNet(input_size, hidden_size, num_classes)

# Train the network
stats = net.train(X_train, y_train, X_val, y_val,
            num_iters=1000, batch_size=200,
            learning_rate=1e-4, learning_rate_decay=0.95,
            reg=0.25, verbose=True)

# Predict on the validation set
val_acc = (net.predict(X_val) == y_val).mean()
train_acc = (net.predict(X_train) == y_train).mean()
print('Validation accuracy: ', val_acc)
print('training accuracy: ',train_acc)
# Out:
# iteration 0 / 1000: loss 2.302954
# iteration 100 / 1000: loss 2.302550
# iteration 200 / 1000: loss 2.297648
# iteration 300 / 1000: loss 2.259602
# iteration 400 / 1000: loss 2.204170
# iteration 500 / 1000: loss 2.118565
# iteration 600 / 1000: loss 2.051535
# iteration 700 / 1000: loss 1.988466
# iteration 800 / 1000: loss 2.006591
# iteration 900 / 1000: loss 1.951473
# Validation accuracy:  0.287
# training accuracy:  0.278530612245

# %% [markdown]
# # Debug the training
# With the default parameters we provided above, you should get a validation accuracy of about 0.29 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the loss function and train / validation accuracies
def plot_stats(stats):
    plt.subplot(2, 1, 1)
    plt.plot(stats['loss_history'],label='loss')
    plt.title('Loss history')
    plt.xlabel('Iteration')
    plt.ylabel('Loss')
    plt.legend(loc='best')

    plt.subplot(2, 1, 2)
    plt.plot(stats['train_acc_history'], label='train')
    plt.plot(stats['val_acc_history'], label='val')
    plt.legend(loc='best')
    plt.title('Classification accuracy history')
    plt.xlabel('Epoch')
    plt.ylabel('Clasification accuracy')
    plt.tight_layout()
    plt.show()

# %%
from cs231n.vis_utils import visualize_grid

# Visualize the weights of the network

def show_net_weights(net):
    W1 = net.params['W1']
    W1 = W1.reshape(32, 32, 3, -1).transpose(3, 0, 1, 2)
    plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
    plt.gca().axis('off')
    plt.show()

show_net_weights(net)

# %% [markdown]
# # Tune your hyperparameters
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than 48% on the validation set. Our best network gets over 52% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on CIFAR-10 as you can, with a fully-connected Neural Network. For every 1% above 52% on the Test set we will award you with one extra bonus point. Feel free implement your own techniques (e.g. PCA to reduce dimensionality, or adding dropout, or adding features to the solver, etc.).

# %%
best_net = None # store the best model into this 

#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model in best_net.                                                            #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# Tweaking hyperparameters by hand can be fun, but you might find it useful to  #
# write code to sweep through possible combinations of hyperparameters          #
# automatically like we did on the previous exercises.                          #
#################################################################################

hidden_layer_sizes = np.array([50, 60, 70])
learning_rates = np.linspace(1e-3,4e-3,10)
regularizations = np.linspace(1e-2, 5e-2, 10)
val_accuracy_list = []
net_list = []

for hls in hidden_layer_sizes:
    for lr in learning_rates:
        for reg in regularizations:
            net = TwoLayerNet(input_size, hls, num_classes)
            stats = net.train(X_train, y_train, X_val, y_val,
                num_iters=1000, batch_size=200,
                learning_rate=lr, learning_rate_decay=0.95,
                reg=reg)
            #plot_stats(stats)
            X_train_acc = np.mean(net.predict(X_train) == y_train)
            X_val_acc = np.mean(net.predict(X_val) == y_val)
            print('hidden_layer_size:%d   learning_rate:%f  regularization:%f  training_acc:%f  validation_acc:%f' % (hls,lr,reg,X_train_acc, X_val_acc))
            val_accuracy_list.append(X_val_acc)
            net_list.append(net)

max_val_index = np.argmax(val_accuracy_list)
print(val_accuracy_list[max_val_index])
best_net = net_list[max_val_index]

#################################################################################
#                               END OF YOUR CODE                                #
#################################################################################
# Out:
# hidden_layer_size:50   learning_rate:0.001000  regularization:0.010000  training_acc:0.495939  validation_acc:0.469000
# hidden_layer_size:50   learning_rate:0.001000  regularization:0.014444  training_acc:0.484633  validation_acc:0.475000
# hidden_layer_size:50   learning_rate:0.001000  regularization:0.018889  training_acc:0.491755  validation_acc:0.464000
# hidden_layer_size:50   learning_rate:0.001000  regularization:0.023333  training_acc:0.490531  validation_acc:0.473000
# hidden_layer_size:50   learning_rate:0.001000  regularization:0.027778  training_acc:0.489878  validation_acc:0.465000
# hidden_layer_size:50   learning_rate:0.001000  regularization:0.032222  training_acc:0.490898  validation_acc:0.473000
# hidden_layer_size:50   learning_rate:0.001000  regularization:0.036667  training_acc:0.495286  validation_acc:0.484000
# hidden_layer_size:50   learning_rate:0.001000  regularization:0.041111  training_acc:0.490000  validation_acc:0.465000
# hidden_layer_size:50   learning_rate:0.001000  regularization:0.045556  training_acc:0.492388  validation_acc:0.473000
# hidden_layer_size:50   learning_rate:0.001000  regularization:0.050000  training_acc:0.487592  validation_acc:0.465000
# hidden_layer_size:50   learning_rate:0.001333  regularization:0.010000  training_acc:0.502061  validation_acc:0.477000
# hidden_layer_size:50   learning_rate:0.001333  regularization:0.014444  training_acc:0.480184  validation_acc:0.445000
# hidden_layer_size:50   learning_rate:0.001333  regularization:0.018889  training_acc:0.498735  validation_acc:0.479000
# hidden_layer_size:50   learning_rate:0.001333  regularization:0.023333  training_acc:0.499551  validation_acc:0.477000
# hidden_layer_size:50   learning_rate:0.001333  regularization:0.027778  training_acc:0.487143  validation_acc:0.472000
# hidden_layer_size:50   learning_rate:0.001333  regularization:0.032222  training_acc:0.502510  validation_acc:0.481000
# hidden_layer_size:50   learning_rate:0.001333  regularization:0.036667  training_acc:0.498592  validation_acc:0.481000
# hidden_layer_size:50   learning_rate:0.001333  regularization:0.041111  training_acc:0.498633  validation_acc:0.477000
# hidden_layer_size:50   learning_rate:0.001333  regularization:0.045556  training_acc:0.504510  validation_acc:0.480000
# hidden_layer_size:50   learning_rate:0.001333  regularization:0.050000  training_acc:0.500245  validation_acc:0.498000
# hidden_layer_size:50   learning_rate:0.001667  regularization:0.010000  training_acc:0.484041  validation_acc:0.453000
# hidden_layer_size:50   learning_rate:0.001667  regularization:0.014444  training_acc:0.502633  validation_acc:0.492000
# hidden_layer_size:50   learning_rate:0.001667  regularization:0.018889  training_acc:0.469735  validation_acc:0.447000
# hidden_layer_size:50   learning_rate:0.001667  regularization:0.023333  training_acc:0.501959  validation_acc:0.478000
# hidden_layer_size:50   learning_rate:0.001667  regularization:0.027778  training_acc:0.509898  validation_acc:0.484000
# hidden_layer_size:50   learning_rate:0.001667  regularization:0.032222  training_acc:0.500265  validation_acc:0.476000
# hidden_layer_size:50   learning_rate:0.001667  regularization:0.036667  training_acc:0.506020  validation_acc:0.462000
# hidden_layer_size:50   learning_rate:0.001667  regularization:0.041111  training_acc:0.510510  validation_acc:0.462000
# hidden_layer_size:50   learning_rate:0.001667  regularization:0.045556  training_acc:0.499918  validation_acc:0.473000
# hidden_layer_size:50   learning_rate:0.001667  regularization:0.050000  training_acc:0.509347  validation_acc:0.476000
# hidden_layer_size:50   learning_rate:0.002000  regularization:0.010000  training_acc:0.486041  validation_acc:0.483000
# hidden_layer_size:50   learning_rate:0.002000  regularization:0.014444  training_acc:0.483204  validation_acc:0.466000
# hidden_layer_size:50   learning_rate:0.002000  regularization:0.018889  training_acc:0.507327  validation_acc:0.472000
# hidden_layer_size:50   learning_rate:0.002000  regularization:0.023333  training_acc:0.496122  validation_acc:0.481000
# hidden_layer_size:50   learning_rate:0.002000  regularization:0.027778  training_acc:0.496878  validation_acc:0.453000
# hidden_layer_size:50   learning_rate:0.002000  regularization:0.032222  training_acc:0.482857  validation_acc:0.460000
# hidden_layer_size:50   learning_rate:0.002000  regularization:0.036667  training_acc:0.497327  validation_acc:0.465000
# hidden_layer_size:50   learning_rate:0.002000  regularization:0.041111  training_acc:0.463265  validation_acc:0.438000
# hidden_layer_size:50   learning_rate:0.002000  regularization:0.045556  training_acc:0.488408  validation_acc:0.470000
# hidden_layer_size:50   learning_rate:0.002000  regularization:0.050000  training_acc:0.501551  validation_acc:0.465000
# hidden_layer_size:50   learning_rate:0.002333  regularization:0.010000  training_acc:0.489633  validation_acc:0.462000
# hidden_layer_size:50   learning_rate:0.002333  regularization:0.014444  training_acc:0.500102  validation_acc:0.468000
# hidden_layer_size:50   learning_rate:0.002333  regularization:0.018889  training_acc:0.480694  validation_acc:0.470000
# hidden_layer_size:50   learning_rate:0.002333  regularization:0.023333  training_acc:0.466367  validation_acc:0.446000
# hidden_layer_size:50   learning_rate:0.002333  regularization:0.027778  training_acc:0.493000  validation_acc:0.473000
# hidden_layer_size:50   learning_rate:0.002333  regularization:0.032222  training_acc:0.502143  validation_acc:0.502000
# hidden_layer_size:50   learning_rate:0.002333  regularization:0.036667  training_acc:0.481531  validation_acc:0.457000
# hidden_layer_size:50   learning_rate:0.002333  regularization:0.041111  training_acc:0.501469  validation_acc:0.467000
# hidden_layer_size:50   learning_rate:0.002333  regularization:0.045556  training_acc:0.494980  validation_acc:0.482000
# hidden_layer_size:50   learning_rate:0.002333  regularization:0.050000  training_acc:0.505735  validation_acc:0.477000
# hidden_layer_size:50   learning_rate:0.002667  regularization:0.010000  training_acc:0.488122  validation_acc:0.450000
# hidden_layer_size:50   learning_rate:0.002667  regularization:0.014444  training_acc:0.498878  validation_acc:0.472000
# hidden_layer_size:50   learning_rate:0.002667  regularization:0.018889  training_acc:0.493939  validation_acc:0.482000
# hidden_layer_size:50   learning_rate:0.002667  regularization:0.023333  training_acc:0.450612  validation_acc:0.413000
# hidden_layer_size:50   learning_rate:0.002667  regularization:0.027778  training_acc:0.494184  validation_acc:0.467000
# hidden_layer_size:50   learning_rate:0.002667  regularization:0.032222  training_acc:0.459061  validation_acc:0.422000
# hidden_layer_size:50   learning_rate:0.002667  regularization:0.036667  training_acc:0.485429  validation_acc:0.467000
# hidden_layer_size:50   learning_rate:0.002667  regularization:0.041111  training_acc:0.491367  validation_acc:0.458000
# hidden_layer_size:50   learning_rate:0.002667  regularization:0.045556  training_acc:0.489469  validation_acc:0.482000
# hidden_layer_size:50   learning_rate:0.002667  regularization:0.050000  training_acc:0.506347  validation_acc:0.488000
# hidden_layer_size:50   learning_rate:0.003000  regularization:0.010000  training_acc:0.494531  validation_acc:0.463000
# hidden_layer_size:50   learning_rate:0.003000  regularization:0.014444  training_acc:0.459429  validation_acc:0.436000
# hidden_layer_size:50   learning_rate:0.003000  regularization:0.018889  training_acc:0.489551  validation_acc:0.464000
# hidden_layer_size:50   learning_rate:0.003000  regularization:0.023333  training_acc:0.474714  validation_acc:0.454000
# hidden_layer_size:50   learning_rate:0.003000  regularization:0.027778  training_acc:0.463143  validation_acc:0.444000
# hidden_layer_size:50   learning_rate:0.003000  regularization:0.032222  training_acc:0.483673  validation_acc:0.459000
# hidden_layer_size:50   learning_rate:0.003000  regularization:0.036667  training_acc:0.474592  validation_acc:0.448000
# hidden_layer_size:50   learning_rate:0.003000  regularization:0.041111  training_acc:0.444714  validation_acc:0.432000
# hidden_layer_size:50   learning_rate:0.003000  regularization:0.045556  training_acc:0.481918  validation_acc:0.458000
# hidden_layer_size:50   learning_rate:0.003000  regularization:0.050000  training_acc:0.486776  validation_acc:0.465000
# hidden_layer_size:50   learning_rate:0.003333  regularization:0.010000  training_acc:0.408490  validation_acc:0.386000
# hidden_layer_size:50   learning_rate:0.003333  regularization:0.014444  training_acc:0.452469  validation_acc:0.447000
# hidden_layer_size:50   learning_rate:0.003333  regularization:0.018889  training_acc:0.464796  validation_acc:0.441000
# hidden_layer_size:50   learning_rate:0.003333  regularization:0.023333  training_acc:0.438980  validation_acc:0.414000
# hidden_layer_size:50   learning_rate:0.003333  regularization:0.027778  training_acc:0.447082  validation_acc:0.436000
# hidden_layer_size:50   learning_rate:0.003333  regularization:0.032222  training_acc:0.461408  validation_acc:0.414000
# hidden_layer_size:50   learning_rate:0.003333  regularization:0.036667  training_acc:0.486224  validation_acc:0.455000
# hidden_layer_size:50   learning_rate:0.003333  regularization:0.041111  training_acc:0.472694  validation_acc:0.427000
# hidden_layer_size:50   learning_rate:0.003333  regularization:0.045556  training_acc:0.493878  validation_acc:0.456000
# hidden_layer_size:50   learning_rate:0.003333  regularization:0.050000  training_acc:0.436367  validation_acc:0.426000
# hidden_layer_size:50   learning_rate:0.003667  regularization:0.010000  training_acc:0.472449  validation_acc:0.446000
# hidden_layer_size:50   learning_rate:0.003667  regularization:0.014444  training_acc:0.407306  validation_acc:0.381000
# hidden_layer_size:50   learning_rate:0.003667  regularization:0.018889  training_acc:0.381878  validation_acc:0.374000
# hidden_layer_size:50   learning_rate:0.003667  regularization:0.023333  training_acc:0.420490  validation_acc:0.402000
# hidden_layer_size:50   learning_rate:0.003667  regularization:0.027778  training_acc:0.441061  validation_acc:0.433000
# hidden_layer_size:50   learning_rate:0.003667  regularization:0.032222  training_acc:0.435082  validation_acc:0.390000
# hidden_layer_size:50   learning_rate:0.003667  regularization:0.036667  training_acc:0.450122  validation_acc:0.443000
# hidden_layer_size:50   learning_rate:0.003667  regularization:0.041111  training_acc:0.471286  validation_acc:0.453000
# hidden_layer_size:50   learning_rate:0.003667  regularization:0.045556  training_acc:0.384020  validation_acc:0.372000
# hidden_layer_size:50   learning_rate:0.003667  regularization:0.050000  training_acc:0.471796  validation_acc:0.434000
# hidden_layer_size:50   learning_rate:0.004000  regularization:0.010000  training_acc:0.100265  validation_acc:0.087000
# hidden_layer_size:50   learning_rate:0.004000  regularization:0.014444  training_acc:0.100265  validation_acc:0.087000
# hidden_layer_size:50   learning_rate:0.004000  regularization:0.018889  training_acc:0.100265  validation_acc:0.087000
# hidden_layer_size:50   learning_rate:0.004000  regularization:0.023333  training_acc:0.420980  validation_acc:0.381000
# hidden_layer_size:50   learning_rate:0.004000  regularization:0.027778  training_acc:0.350408  validation_acc:0.358000
# hidden_layer_size:50   learning_rate:0.004000  regularization:0.032222  training_acc:0.100265  validation_acc:0.087000
# hidden_layer_size:50   learning_rate:0.004000  regularization:0.036667  training_acc:0.100265  validation_acc:0.087000
# hidden_layer_size:50   learning_rate:0.004000  regularization:0.041111  training_acc:0.100265  validation_acc:0.087000
# hidden_layer_size:50   learning_rate:0.004000  regularization:0.045556  training_acc:0.100265  validation_acc:0.087000
# hidden_layer_size:50   learning_rate:0.004000  regularization:0.050000  training_acc:0.100265  validation_acc:0.087000
# hidden_layer_size:60   learning_rate:0.001000  regularization:0.010000  training_acc:0.495776  validation_acc:0.474000
# hidden_layer_size:60   learning_rate:0.001000  regularization:0.014444  training_acc:0.502735  validation_acc:0.485000
# hidden_layer_size:60   learning_rate:0.001000  regularization:0.018889  training_acc:0.498816  validation_acc:0.480000
# hidden_layer_size:60   learning_rate:0.001000  regularization:0.023333  training_acc:0.488735  validation_acc:0.476000
# hidden_layer_size:60   learning_rate:0.001000  regularization:0.027778  training_acc:0.500204  validation_acc:0.481000
# hidden_layer_size:60   learning_rate:0.001000  regularization:0.032222  training_acc:0.500776  validation_acc:0.474000
# hidden_layer_size:60   learning_rate:0.001000  regularization:0.036667  training_acc:0.492551  validation_acc:0.484000
# hidden_layer_size:60   learning_rate:0.001000  regularization:0.041111  training_acc:0.494469  validation_acc:0.458000
# hidden_layer_size:60   learning_rate:0.001000  regularization:0.045556  training_acc:0.499122  validation_acc:0.469000
# hidden_layer_size:60   learning_rate:0.001000  regularization:0.050000  training_acc:0.495449  validation_acc:0.472000
# hidden_layer_size:60   learning_rate:0.001333  regularization:0.010000  training_acc:0.510347  validation_acc:0.472000
# hidden_layer_size:60   learning_rate:0.001333  regularization:0.014444  training_acc:0.507122  validation_acc:0.467000
# hidden_layer_size:60   learning_rate:0.001333  regularization:0.018889  training_acc:0.506673  validation_acc:0.475000
# hidden_layer_size:60   learning_rate:0.001333  regularization:0.023333  training_acc:0.506612  validation_acc:0.491000
# hidden_layer_size:60   learning_rate:0.001333  regularization:0.027778  training_acc:0.498306  validation_acc:0.488000
# hidden_layer_size:60   learning_rate:0.001333  regularization:0.032222  training_acc:0.502694  validation_acc:0.468000
# hidden_layer_size:60   learning_rate:0.001333  regularization:0.036667  training_acc:0.509163  validation_acc:0.494000
# hidden_layer_size:60   learning_rate:0.001333  regularization:0.041111  training_acc:0.506857  validation_acc:0.472000
# hidden_layer_size:60   learning_rate:0.001333  regularization:0.045556  training_acc:0.499816  validation_acc:0.474000
# hidden_layer_size:60   learning_rate:0.001333  regularization:0.050000  training_acc:0.501837  validation_acc:0.480000
# hidden_layer_size:60   learning_rate:0.001667  regularization:0.010000  training_acc:0.511980  validation_acc:0.482000
# hidden_layer_size:60   learning_rate:0.001667  regularization:0.014444  training_acc:0.502592  validation_acc:0.469000
# hidden_layer_size:60   learning_rate:0.001667  regularization:0.018889  training_acc:0.506245  validation_acc:0.485000
# hidden_layer_size:60   learning_rate:0.001667  regularization:0.023333  training_acc:0.500776  validation_acc:0.481000
# hidden_layer_size:60   learning_rate:0.001667  regularization:0.027778  training_acc:0.515449  validation_acc:0.472000
# hidden_layer_size:60   learning_rate:0.001667  regularization:0.032222  training_acc:0.515939  validation_acc:0.488000
# hidden_layer_size:60   learning_rate:0.001667  regularization:0.036667  training_acc:0.507592  validation_acc:0.479000
# hidden_layer_size:60   learning_rate:0.001667  regularization:0.041111  training_acc:0.513449  validation_acc:0.504000
# hidden_layer_size:60   learning_rate:0.001667  regularization:0.045556  training_acc:0.483878  validation_acc:0.474000
# hidden_layer_size:60   learning_rate:0.001667  regularization:0.050000  training_acc:0.496388  validation_acc:0.495000
# hidden_layer_size:60   learning_rate:0.002000  regularization:0.010000  training_acc:0.520612  validation_acc:0.497000
# hidden_layer_size:60   learning_rate:0.002000  regularization:0.014444  training_acc:0.495551  validation_acc:0.459000
# hidden_layer_size:60   learning_rate:0.002000  regularization:0.018889  training_acc:0.506327  validation_acc:0.470000
# hidden_layer_size:60   learning_rate:0.002000  regularization:0.023333  training_acc:0.510918  validation_acc:0.498000
# hidden_layer_size:60   learning_rate:0.002000  regularization:0.027778  training_acc:0.516020  validation_acc:0.474000
# hidden_layer_size:60   learning_rate:0.002000  regularization:0.032222  training_acc:0.499469  validation_acc:0.458000
# hidden_layer_size:60   learning_rate:0.002000  regularization:0.036667  training_acc:0.514347  validation_acc:0.501000
# hidden_layer_size:60   learning_rate:0.002000  regularization:0.041111  training_acc:0.519224  validation_acc:0.488000
# hidden_layer_size:60   learning_rate:0.002000  regularization:0.045556  training_acc:0.503571  validation_acc:0.493000
# hidden_layer_size:60   learning_rate:0.002000  regularization:0.050000  training_acc:0.499204  validation_acc:0.467000
# hidden_layer_size:60   learning_rate:0.002333  regularization:0.010000  training_acc:0.479102  validation_acc:0.450000
# hidden_layer_size:60   learning_rate:0.002333  regularization:0.014444  training_acc:0.475551  validation_acc:0.461000
# hidden_layer_size:60   learning_rate:0.002333  regularization:0.018889  training_acc:0.474816  validation_acc:0.469000
# hidden_layer_size:60   learning_rate:0.002333  regularization:0.023333  training_acc:0.508143  validation_acc:0.481000
# hidden_layer_size:60   learning_rate:0.002333  regularization:0.027778  training_acc:0.502735  validation_acc:0.470000
# hidden_layer_size:60   learning_rate:0.002333  regularization:0.032222  training_acc:0.460755  validation_acc:0.444000
# hidden_layer_size:60   learning_rate:0.002333  regularization:0.036667  training_acc:0.505837  validation_acc:0.474000
# hidden_layer_size:60   learning_rate:0.002333  regularization:0.041111  training_acc:0.498796  validation_acc:0.454000
# hidden_layer_size:60   learning_rate:0.002333  regularization:0.045556  training_acc:0.473653  validation_acc:0.430000
# hidden_layer_size:60   learning_rate:0.002333  regularization:0.050000  training_acc:0.499020  validation_acc:0.480000
# hidden_layer_size:60   learning_rate:0.002667  regularization:0.010000  training_acc:0.498020  validation_acc:0.468000
# hidden_layer_size:60   learning_rate:0.002667  regularization:0.014444  training_acc:0.482878  validation_acc:0.460000
# hidden_layer_size:60   learning_rate:0.002667  regularization:0.018889  training_acc:0.468857  validation_acc:0.449000
# hidden_layer_size:60   learning_rate:0.002667  regularization:0.023333  training_acc:0.509184  validation_acc:0.482000
# hidden_layer_size:60   learning_rate:0.002667  regularization:0.027778  training_acc:0.488082  validation_acc:0.458000
# hidden_layer_size:60   learning_rate:0.002667  regularization:0.032222  training_acc:0.466490  validation_acc:0.443000
# hidden_layer_size:60   learning_rate:0.002667  regularization:0.036667  training_acc:0.485347  validation_acc:0.462000
# hidden_layer_size:60   learning_rate:0.002667  regularization:0.041111  training_acc:0.466306  validation_acc:0.454000
# hidden_layer_size:60   learning_rate:0.002667  regularization:0.045556  training_acc:0.497204  validation_acc:0.472000
# hidden_layer_size:60   learning_rate:0.002667  regularization:0.050000  training_acc:0.500571  validation_acc:0.479000
# hidden_layer_size:60   learning_rate:0.003000  regularization:0.010000  training_acc:0.433122  validation_acc:0.431000
# hidden_layer_size:60   learning_rate:0.003000  regularization:0.014444  training_acc:0.471898  validation_acc:0.444000
# hidden_layer_size:60   learning_rate:0.003000  regularization:0.018889  training_acc:0.460653  validation_acc:0.449000
# hidden_layer_size:60   learning_rate:0.003000  regularization:0.023333  training_acc:0.484980  validation_acc:0.473000
# hidden_layer_size:60   learning_rate:0.003000  regularization:0.027778  training_acc:0.477531  validation_acc:0.481000
# hidden_layer_size:60   learning_rate:0.003000  regularization:0.032222  training_acc:0.473469  validation_acc:0.434000
# hidden_layer_size:60   learning_rate:0.003000  regularization:0.036667  training_acc:0.480694  validation_acc:0.468000
# hidden_layer_size:60   learning_rate:0.003000  regularization:0.041111  training_acc:0.484776  validation_acc:0.452000
# hidden_layer_size:60   learning_rate:0.003000  regularization:0.045556  training_acc:0.419102  validation_acc:0.406000
# hidden_layer_size:60   learning_rate:0.003000  regularization:0.050000  training_acc:0.482347  validation_acc:0.457000
# hidden_layer_size:60   learning_rate:0.003333  regularization:0.010000  training_acc:0.465429  validation_acc:0.436000
# hidden_layer_size:60   learning_rate:0.003333  regularization:0.014444  training_acc:0.462449  validation_acc:0.438000
# hidden_layer_size:60   learning_rate:0.003333  regularization:0.018889  training_acc:0.468102  validation_acc:0.457000
# hidden_layer_size:60   learning_rate:0.003333  regularization:0.023333  training_acc:0.465796  validation_acc:0.462000
# hidden_layer_size:60   learning_rate:0.003333  regularization:0.027778  training_acc:0.442041  validation_acc:0.415000
# hidden_layer_size:60   learning_rate:0.003333  regularization:0.032222  training_acc:0.473735  validation_acc:0.461000
# hidden_layer_size:60   learning_rate:0.003333  regularization:0.036667  training_acc:0.477673  validation_acc:0.470000
# hidden_layer_size:60   learning_rate:0.003333  regularization:0.041111  training_acc:0.484204  validation_acc:0.471000
# hidden_layer_size:60   learning_rate:0.003333  regularization:0.045556  training_acc:0.458102  validation_acc:0.446000
# hidden_layer_size:60   learning_rate:0.003333  regularization:0.050000  training_acc:0.466531  validation_acc:0.438000
# hidden_layer_size:60   learning_rate:0.003667  regularization:0.010000  training_acc:0.452163  validation_acc:0.433000
# hidden_layer_size:60   learning_rate:0.003667  regularization:0.014444  training_acc:0.468796  validation_acc:0.449000
# hidden_layer_size:60   learning_rate:0.003667  regularization:0.018889  training_acc:0.382000  validation_acc:0.348000
# hidden_layer_size:60   learning_rate:0.003667  regularization:0.023333  training_acc:0.428796  validation_acc:0.407000
# hidden_layer_size:60   learning_rate:0.003667  regularization:0.027778  training_acc:0.463224  validation_acc:0.438000
# hidden_layer_size:60   learning_rate:0.003667  regularization:0.032222  training_acc:0.452592  validation_acc:0.437000
# hidden_layer_size:60   learning_rate:0.003667  regularization:0.036667  training_acc:0.407816  validation_acc:0.379000
# hidden_layer_size:60   learning_rate:0.003667  regularization:0.041111  training_acc:0.468612  validation_acc:0.468000
# hidden_layer_size:60   learning_rate:0.003667  regularization:0.045556  training_acc:0.399816  validation_acc:0.376000
# hidden_layer_size:60   learning_rate:0.003667  regularization:0.050000  training_acc:0.100265  validation_acc:0.087000
# hidden_layer_size:60   learning_rate:0.004000  regularization:0.010000  training_acc:0.100265  validation_acc:0.087000
# hidden_layer_size:60   learning_rate:0.004000  regularization:0.014444  training_acc:0.447653  validation_acc:0.427000
# hidden_layer_size:60   learning_rate:0.004000  regularization:0.018889  training_acc:0.100265  validation_acc:0.087000
# hidden_layer_size:60   learning_rate:0.004000  regularization:0.023333  training_acc:0.100265  validation_acc:0.087000
# hidden_layer_size:60   learning_rate:0.004000  regularization:0.027778  training_acc:0.100265  validation_acc:0.087000
# hidden_layer_size:60   learning_rate:0.004000  regularization:0.032222  training_acc:0.100265  validation_acc:0.087000
# hidden_layer_size:60   learning_rate:0.004000  regularization:0.036667  training_acc:0.100265  validation_acc:0.087000
# hidden_layer_size:60   learning_rate:0.004000  regularization:0.041111  training_acc:0.398653  validation_acc:0.383000
# hidden_layer_size:60   learning_rate:0.004000  regularization:0.045556  training_acc:0.100265  validation_acc:0.087000
# hidden_layer_size:60   learning_rate:0.004000  regularization:0.050000  training_acc:0.100265  validation_acc:0.087000
# hidden_layer_size:70   learning_rate:0.001000  regularization:0.010000  training_acc:0.493061  validation_acc:0.490000
# hidden_layer_size:70   learning_rate:0.001000  regularization:0.014444  training_acc:0.497694  validation_acc:0.481000
# hidden_layer_size:70   learning_rate:0.001000  regularization:0.018889  training_acc:0.500449  validation_acc:0.472000
# hidden_layer_size:70   learning_rate:0.001000  regularization:0.023333  training_acc:0.496837  validation_acc:0.472000
# hidden_layer_size:70   learning_rate:0.001000  regularization:0.027778  training_acc:0.504306  validation_acc:0.472000
# hidden_layer_size:70   learning_rate:0.001000  regularization:0.032222  training_acc:0.484061  validation_acc:0.473000
# hidden_layer_size:70   learning_rate:0.001000  regularization:0.036667  training_acc:0.498449  validation_acc:0.471000
# hidden_layer_size:70   learning_rate:0.001000  regularization:0.041111  training_acc:0.502918  validation_acc:0.492000
# hidden_layer_size:70   learning_rate:0.001000  regularization:0.045556  training_acc:0.501306  validation_acc:0.489000
# hidden_layer_size:70   learning_rate:0.001000  regularization:0.050000  training_acc:0.502204  validation_acc:0.482000
# hidden_layer_size:70   learning_rate:0.001333  regularization:0.010000  training_acc:0.509898  validation_acc:0.475000
# hidden_layer_size:70   learning_rate:0.001333  regularization:0.014444  training_acc:0.507347  validation_acc:0.475000
# hidden_layer_size:70   learning_rate:0.001333  regularization:0.018889  training_acc:0.495755  validation_acc:0.465000
# hidden_layer_size:70   learning_rate:0.001333  regularization:0.023333  training_acc:0.518204  validation_acc:0.492000
# hidden_layer_size:70   learning_rate:0.001333  regularization:0.027778  training_acc:0.511449  validation_acc:0.477000
# hidden_layer_size:70   learning_rate:0.001333  regularization:0.032222  training_acc:0.519184  validation_acc:0.503000
# hidden_layer_size:70   learning_rate:0.001333  regularization:0.036667  training_acc:0.502816  validation_acc:0.481000
# hidden_layer_size:70   learning_rate:0.001333  regularization:0.041111  training_acc:0.499816  validation_acc:0.473000
# hidden_layer_size:70   learning_rate:0.001333  regularization:0.045556  training_acc:0.513286  validation_acc:0.491000
# hidden_layer_size:70   learning_rate:0.001333  regularization:0.050000  training_acc:0.507102  validation_acc:0.491000
# hidden_layer_size:70   learning_rate:0.001667  regularization:0.010000  training_acc:0.508735  validation_acc:0.468000
# hidden_layer_size:70   learning_rate:0.001667  regularization:0.014444  training_acc:0.488020  validation_acc:0.465000
# hidden_layer_size:70   learning_rate:0.001667  regularization:0.018889  training_acc:0.520449  validation_acc:0.483000
# hidden_layer_size:70   learning_rate:0.001667  regularization:0.023333  training_acc:0.514673  validation_acc:0.497000
# hidden_layer_size:70   learning_rate:0.001667  regularization:0.027778  training_acc:0.508286  validation_acc:0.472000
# hidden_layer_size:70   learning_rate:0.001667  regularization:0.032222  training_acc:0.516551  validation_acc:0.489000
# hidden_layer_size:70   learning_rate:0.001667  regularization:0.036667  training_acc:0.504367  validation_acc:0.500000
# hidden_layer_size:70   learning_rate:0.001667  regularization:0.041111  training_acc:0.513082  validation_acc:0.462000
# hidden_layer_size:70   learning_rate:0.001667  regularization:0.045556  training_acc:0.515306  validation_acc:0.482000
# hidden_layer_size:70   learning_rate:0.001667  regularization:0.050000  training_acc:0.505347  validation_acc:0.491000
# hidden_layer_size:70   learning_rate:0.002000  regularization:0.010000  training_acc:0.500490  validation_acc:0.466000
# hidden_layer_size:70   learning_rate:0.002000  regularization:0.014444  training_acc:0.486980  validation_acc:0.453000
# hidden_layer_size:70   learning_rate:0.002000  regularization:0.018889  training_acc:0.519510  validation_acc:0.494000
# hidden_layer_size:70   learning_rate:0.002000  regularization:0.023333  training_acc:0.506776  validation_acc:0.477000
# hidden_layer_size:70   learning_rate:0.002000  regularization:0.027778  training_acc:0.509265  validation_acc:0.483000
# hidden_layer_size:70   learning_rate:0.002000  regularization:0.032222  training_acc:0.498571  validation_acc:0.457000
# hidden_layer_size:70   learning_rate:0.002000  regularization:0.036667  training_acc:0.507265  validation_acc:0.472000
# hidden_layer_size:70   learning_rate:0.002000  regularization:0.041111  training_acc:0.508388  validation_acc:0.466000
# hidden_layer_size:70   learning_rate:0.002000  regularization:0.045556  training_acc:0.502184  validation_acc:0.456000
# hidden_layer_size:70   learning_rate:0.002000  regularization:0.050000  training_acc:0.469388  validation_acc:0.465000
# hidden_layer_size:70   learning_rate:0.002333  regularization:0.010000  training_acc:0.516367  validation_acc:0.503000
# hidden_layer_size:70   learning_rate:0.002333  regularization:0.014444  training_acc:0.474878  validation_acc:0.442000
# hidden_layer_size:70   learning_rate:0.002333  regularization:0.018889  training_acc:0.499286  validation_acc:0.468000
# hidden_layer_size:70   learning_rate:0.002333  regularization:0.023333  training_acc:0.511980  validation_acc:0.473000
# hidden_layer_size:70   learning_rate:0.002333  regularization:0.027778  training_acc:0.496469  validation_acc:0.473000
# hidden_layer_size:70   learning_rate:0.002333  regularization:0.032222  training_acc:0.514796  validation_acc:0.474000
# hidden_layer_size:70   learning_rate:0.002333  regularization:0.036667  training_acc:0.513408  validation_acc:0.479000
# hidden_layer_size:70   learning_rate:0.002333  regularization:0.041111  training_acc:0.483408  validation_acc:0.470000
# hidden_layer_size:70   learning_rate:0.002333  regularization:0.045556  training_acc:0.482000  validation_acc:0.454000
# hidden_layer_size:70   learning_rate:0.002333  regularization:0.050000  training_acc:0.502980  validation_acc:0.473000
# hidden_layer_size:70   learning_rate:0.002667  regularization:0.010000  training_acc:0.486633  validation_acc:0.464000
# hidden_layer_size:70   learning_rate:0.002667  regularization:0.014444  training_acc:0.442327  validation_acc:0.430000
# hidden_layer_size:70   learning_rate:0.002667  regularization:0.018889  training_acc:0.506388  validation_acc:0.508000
# hidden_layer_size:70   learning_rate:0.002667  regularization:0.023333  training_acc:0.478531  validation_acc:0.449000
# hidden_layer_size:70   learning_rate:0.002667  regularization:0.027778  training_acc:0.492224  validation_acc:0.467000
# hidden_layer_size:70   learning_rate:0.002667  regularization:0.032222  training_acc:0.495980  validation_acc:0.484000
# hidden_layer_size:70   learning_rate:0.002667  regularization:0.036667  training_acc:0.470755  validation_acc:0.437000
# hidden_layer_size:70   learning_rate:0.002667  regularization:0.041111  training_acc:0.509673  validation_acc:0.477000
# hidden_layer_size:70   learning_rate:0.002667  regularization:0.045556  training_acc:0.503102  validation_acc:0.472000
# hidden_layer_size:70   learning_rate:0.002667  regularization:0.050000  training_acc:0.473714  validation_acc:0.454000
# hidden_layer_size:70   learning_rate:0.003000  regularization:0.010000  training_acc:0.469490  validation_acc:0.456000
# hidden_layer_size:70   learning_rate:0.003000  regularization:0.014444  training_acc:0.489898  validation_acc:0.462000
# hidden_layer_size:70   learning_rate:0.003000  regularization:0.018889  training_acc:0.508041  validation_acc:0.483000
# hidden_layer_size:70   learning_rate:0.003000  regularization:0.023333  training_acc:0.478755  validation_acc:0.454000
# hidden_layer_size:70   learning_rate:0.003000  regularization:0.027778  training_acc:0.478694  validation_acc:0.456000
# hidden_layer_size:70   learning_rate:0.003000  regularization:0.032222  training_acc:0.479245  validation_acc:0.444000
# hidden_layer_size:70   learning_rate:0.003000  regularization:0.036667  training_acc:0.463531  validation_acc:0.442000
# hidden_layer_size:70   learning_rate:0.003000  regularization:0.041111  training_acc:0.462796  validation_acc:0.450000
# hidden_layer_size:70   learning_rate:0.003000  regularization:0.045556  training_acc:0.475592  validation_acc:0.445000
# hidden_layer_size:70   learning_rate:0.003000  regularization:0.050000  training_acc:0.427612  validation_acc:0.408000
# hidden_layer_size:70   learning_rate:0.003333  regularization:0.010000  training_acc:0.409959  validation_acc:0.392000
# hidden_layer_size:70   learning_rate:0.003333  regularization:0.014444  training_acc:0.384755  validation_acc:0.373000
# hidden_layer_size:70   learning_rate:0.003333  regularization:0.018889  training_acc:0.462286  validation_acc:0.434000
# hidden_layer_size:70   learning_rate:0.003333  regularization:0.023333  training_acc:0.453143  validation_acc:0.410000
# hidden_layer_size:70   learning_rate:0.003333  regularization:0.027778  training_acc:0.414571  validation_acc:0.382000
# hidden_layer_size:70   learning_rate:0.003333  regularization:0.032222  training_acc:0.453735  validation_acc:0.438000
# hidden_layer_size:70   learning_rate:0.003333  regularization:0.036667  training_acc:0.452082  validation_acc:0.419000
# hidden_layer_size:70   learning_rate:0.003333  regularization:0.041111  training_acc:0.437306  validation_acc:0.440000
# hidden_layer_size:70   learning_rate:0.003333  regularization:0.045556  training_acc:0.424694  validation_acc:0.415000
# hidden_layer_size:70   learning_rate:0.003333  regularization:0.050000  training_acc:0.456939  validation_acc:0.446000
# hidden_layer_size:70   learning_rate:0.003667  regularization:0.010000  training_acc:0.377918  validation_acc:0.350000
# hidden_layer_size:70   learning_rate:0.003667  regularization:0.014444  training_acc:0.471898  validation_acc:0.426000
# hidden_layer_size:70   learning_rate:0.003667  regularization:0.018889  training_acc:0.401694  validation_acc:0.382000
# hidden_layer_size:70   learning_rate:0.003667  regularization:0.023333  training_acc:0.488224  validation_acc:0.452000
# hidden_layer_size:70   learning_rate:0.003667  regularization:0.027778  training_acc:0.455735  validation_acc:0.462000
# hidden_layer_size:70   learning_rate:0.003667  regularization:0.032222  training_acc:0.100265  validation_acc:0.087000
# hidden_layer_size:70   learning_rate:0.003667  regularization:0.036667  training_acc:0.416571  validation_acc:0.401000
# hidden_layer_size:70   learning_rate:0.003667  regularization:0.041111  training_acc:0.453694  validation_acc:0.419000
# hidden_layer_size:70   learning_rate:0.003667  regularization:0.045556  training_acc:0.435796  validation_acc:0.425000
# hidden_layer_size:70   learning_rate:0.003667  regularization:0.050000  training_acc:0.100265  validation_acc:0.087000
# hidden_layer_size:70   learning_rate:0.004000  regularization:0.010000  training_acc:0.100265  validation_acc:0.087000
# hidden_layer_size:70   learning_rate:0.004000  regularization:0.014444  training_acc:0.100265  validation_acc:0.087000
# hidden_layer_size:70   learning_rate:0.004000  regularization:0.018889  training_acc:0.100265  validation_acc:0.087000
# hidden_layer_size:70   learning_rate:0.004000  regularization:0.023333  training_acc:0.100265  validation_acc:0.087000
# hidden_layer_size:70   learning_rate:0.004000  regularization:0.027778  training_acc:0.100265  validation_acc:0.087000
# hidden_layer_size:70   learning_rate:0.004000  regularization:0.032222  training_acc:0.100265  validation_acc:0.087000
# hidden_layer_size:70   learning_rate:0.004000  regularization:0.036667  training_acc:0.100265  validation_acc:0.087000
# hidden_layer_size:70   learning_rate:0.004000  regularization:0.041111  training_acc:0.100265  validation_acc:0.087000
# hidden_layer_size:70   learning_rate:0.004000  regularization:0.045556  training_acc:0.406653  validation_acc:0.396000
# hidden_layer_size:70   learning_rate:0.004000  regularization:0.050000  training_acc:0.100265  validation_acc:0.087000
# 0.508
# /home/harpreet/Desktop/cs231n/assignment1/cs231n/classifiers/neural_net.py:105: RuntimeWarning: divide by zero encountered in log
#   loss = -1*np.sum(np.log(softmax_scores))
# /home/harpreet/Desktop/cs231n/assignment1/cs231n/classifiers/neural_net.py:100: RuntimeWarning: overflow encountered in exp
#   exp_scores = np.exp(scores)
# /home/harpreet/Desktop/cs231n/assignment1/cs231n/classifiers/neural_net.py:103: RuntimeWarning: invalid value encountered in true_divide
#   softmax_scores = label_scores.astype(float)/sum_scores
# /home/harpreet/Desktop/cs231n/assignment1/cs231n/classifiers/neural_net.py:119: RuntimeWarning: invalid value encountered in true_divide
#   dscores = exp_scores/sum_scores[:,np.newaxis]
# /home/harpreet/Desktop/cs231n/assignment1/cs231n/classifiers/neural_net.py:127: RuntimeWarning: invalid value encountered in less_equal
#   dhidden[ReLU_output <= 0] = 0

# %%
# visualize the weights of the best network
show_net_weights(best_net)

# %% [markdown]
# # Run on the test set
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 48%.
#
# **We will give you extra bonus point for every 1% of accuracy above 52%.**

# %%
test_acc = (best_net.predict(X_test) == y_test).mean()
print('Test accuracy: ', test_acc)
# Out:
# Test accuracy:  0.458
